# %%
import numpy as np

# %%
arr1s = np.ones((2))

# %%
print(arr1s)
# Out:
# [1. 1.]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()

x = np.linspace(0, 10, 30)
print(type(x))
plt.plot(x, np.sin(x))

plt.show()
# Out:
# <class 'numpy.ndarray'>
